# %% [raw]
# 说明：
#     确定9x9数独板是否有效。只有填充的单元格需要根据以下规则进行验证：
#     1、每行必须包含数字1-9（无重复）。
#     2、每列必须包含数字1-9，不能重复。
#     3、网格的9个3x3子框中的每个必须包含数字1-9（无重复）。
#
# Sudoku板可能会部分填充，其中的空白单元格中会填充字符“。”。
#
# Example 1:
#     Input:
#         [
#           ["5","3",".",".","7",".",".",".","."],
#           ["6",".",".","1","9","5",".",".","."],
#           [".","9","8",".",".",".",".","6","."],
#           ["8",".",".",".","6",".",".",".","3"],
#           ["4",".",".","8",".","3",".",".","1"],
#           ["7",".",".",".","2",".",".",".","6"],
#           [".","6",".",".",".",".","2","8","."],
#           [".",".",".","4","1","9",".",".","5"],
#           [".",".",".",".","8",".",".","7","9"]
#         ]
#     Output: true
#
# 注意：
#     1、数独板（部分填充）可能有效，但不一定是可解的。
#     2、只有填充的单元格需要根据上述规则进行验证。
#     3、给定的板只包含数字1-9和字符“.”。
#     4、给定的板大小总是9x9。
