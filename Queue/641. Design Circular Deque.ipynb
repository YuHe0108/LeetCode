# %% [raw]
# 说明：
#     设计您的循环双端队列(双端队列)的实现。您的实现应该支持以下操作：MyCircularDeque(K)：
#     1、构造函数，将deque的大小设置为k。
#     2、insert tFront()：在Deque的前面添加一项。如果操作成功，则返回true。
#     3、Insert tLast()：在Deque的后面添加一项。如果操作成功，则返回true。
#     4、Delete eFront()：从Deque的前面删除一个项目。如果操作成功，则返回true。
#     5、Delete eLast()：从Deque的后面删除一项。如果操作成功，则返回true。
#     6、GetFront()：从Deque中获取前面的项。如果双队列为空，则返回-1。
#     7、GetRear()：从Deque获取最后一项。如果双队列为空，则返回-1。
#     8、IsEmpty()：检查Deque是否为空。IsFull()：检查Deque是否已满。

# %%
class MyCircularDeque:

    def __init__(self, k: int):
        """
        Initialize your data structure here. Set the size of the deque to be k.
        """
        self.k = k
        self.cir_queue = []

    def insertFront(self, value: int) -> bool:
        """
        Adds an item at the front of Deque. Return true if the operation is successful.
        """
        if len(self.cir_queue) < self.k:
            self.cir_queue.insert(0, value)
            return True
        return False
        

    def insertLast(self, value: int) -> bool:
        """
        Adds an item at the rear of Deque. Return true if the operation is successful.
        """
        if len(self.cir_queue) < self.k:
            self.cir_queue.append(value)
            return True
        return False

    def deleteFront(self) -> bool:
        """
        Deletes an item from the front of Deque. Return true if the operation is successful.
        """
        if len(self.cir_queue) > 0:
            self.cir_queue.pop(0)
            return True
        return False
        

    def deleteLast(self) -> bool:
        """
        Deletes an item from the rear of Deque. Return true if the operation is successful.
        """
        if len(self.cir_queue) > 0:
            self.cir_queue.pop()
            return True
        return False
        

    def getFront(self) -> int:
        """
        Get the front item from the deque.
        """
        if len(self.cir_queue) > 0:
            return self.cir_queue[0]
        return -1

    def getRear(self) -> int:
        """
        Get the last item from the deque.
        """
        if len(self.cir_queue) > 0:
            return self.cir_queue[-1]
        return -1
        

    def isEmpty(self) -> bool:
        """
        Checks whether the circular deque is empty or not.
        """
        if len(self.cir_queue) > 0:
            return False
        return True

        

    def isFull(self) -> bool:
        """
        Checks whether the circular deque is full or not.
        """
        if len(self.cir_queue) == self.k:
            return True
        return False
        


# Your MyCircularDeque object will be instantiated and called as such:
# obj = MyCircularDeque(k)
# param_1 = obj.insertFront(value)
# param_2 = obj.insertLast(value)
# param_3 = obj.deleteFront()
# param_4 = obj.deleteLast()
# param_5 = obj.getFront()
# param_6 = obj.getRear()
# param_7 = obj.isEmpty()
# param_8 = obj.isFull()

# %%
class MyCircularDeque:

    def __init__(self, k: int):
        """
        Initialize your data structure here. Set the size of the deque to be k.
        """
        self.arr = [0] * k
        self.front = 0
        self.rear = 0
        self.ele_counts = 0

    def insertFront(self, value: int) -> bool:
        """
        Adds an item at the front of Deque. Return true if the operation is successful.
        """
        if self.isFull():
            return False
        self.ele_counts += 1
        self.arr[self.front] = value
        self.front = (self.front - 1 + len(self.arr)) % len(self.arr)
        return True

    def insertLast(self, value: int) -> bool:
        """
        Adds an item at the rear of Deque. Return true if the operation is successful.
        """
        if self.isFull():
            return False
        self.ele_counts += 1
        self.rear = (self.rear + 1) % len(self.arr)
        self.arr[self.rear] = value
        return True

    def deleteFront(self) -> bool:
        """
        Deletes an item from the front of Deque. Return true if the operation is successful.
        """
        if self.isEmpty():
            return False
        self.front = (self.front + 1) % len(self.arr)
        self.ele_counts -= 1
        return True

    def deleteLast(self) -> bool:
        """
        Deletes an item from the rear of Deque. Return true if the operation is successful.
        """
        if self.isEmpty():
            return False
        self.rear = (self.rear - 1) % len(self.arr)
        self.ele_counts -= 1
        return True

    def getFront(self) -> int:
        """
        Get the front item from the deque.
        """
        if self.isEmpty():
            return -1
        pos = (self.front + 1) % len(self.arr)
        return self.arr[pos]

    def getRear(self) -> int:
        """
        Get the last item from the deque.
        """
        if self.isEmpty():
            return -1
        return self.arr[self.rear]

    def isEmpty(self) -> bool:
        """
        Checks whether the circular deque is empty or not.
        """
        return self.ele_counts == 0

    def isFull(self) -> bool:
        """
        Checks whether the circular deque is full or not.
        """
        return self.ele_counts == len(self.arr)
